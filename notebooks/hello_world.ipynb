# %% [markdown]
# # Hello World!
#
# Here's an example notebook with some documentation on how to access CMIP data.

# %%
# %matplotlib inline

import xarray as xr
import intake

# util.py is in the local directory
# it contains code that is common across project notebooks
# or routines that are too extensive and might otherwise clutter
# the notebook design
import util
# Out:
# /glade/work/mclong/miniconda3/envs/CMIP6-201910/lib/python3.7/site-packages/intake/source/discovery.py:136: FutureWarning: The drivers ['stac-catalog', 'stac-collection', 'stac-item'] do not specify entry_points and were only discovered via a package scan. This may break in a future release of intake. The packages should be updated.
#   FutureWarning)

# %%
print('hello world!')
# Out:
# hello world!

# %% [markdown]
# ## Demonstrate how spin-up a dask cluster
# Syntax is different if on an NCAR machine versus the cloud.

# %%
if util.is_ncar_host():
    from ncar_jobqueue import NCARCluster
    cluster = NCARCluster(project='UCGD0006')
    cluster.adapt(minimum_jobs=1, maximum_jobs=40)
else:
    from dask_kubernetes import KubeCluster
    cluster = KubeCluster()
    cluster.adapt(minimum=1, maximum=40)
cluster
# Out:
# /glade/work/mclong/miniconda3/envs/CMIP6-201910/lib/python3.7/site-packages/distributed/dashboard/core.py:72: UserWarning:
# Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the diagnostics dashboard on a random port instead.
#   warnings.warn("\n" + msg)
# VBox(children=(HTML(value='<h2>NCARCluster</h2>'), HBox(children=(HTML(value='\n<div>\n  <style scoped>\n    .…

# %%
from dask.distributed import Client
client = Client(cluster) # Connect this local process to remote workers
client
# Out:
# <Client: 'tcp://128.117.181.208:46641' processes=0 threads=0, memory=0 B>

# %% [markdown]
# ## Demonstrate how to use `intake-esm`
# [Intake-esm](https://intake-esm.readthedocs.io) is a data cataloging utility that facilitates access to CMIP data. It's pretty awesome.
#
# An `intake-esm` collection object establishes a link to a database that contains file locations and associated metadata (i.e., which experiement, model, the come from).
#
# ### Opening a collection
# First step is to open the collection by pointing the collection definition file, which is a JSON file that conforms to the [ESM Collection Specification](https://github.com/NCAR/esm-collection-spec).
#
# The collection JSON files are stored locally in this repository for purposes of reproducibility---and because Cheyenne compute nodes don't have Internet access.
#
# The primary source for these files is the [intake-esm-datastore](https://github.com/NCAR/intake-esm-datastore) repository. Any changes made to these files should be pulled from that repo. For instance, the Pangeo cloud collection is available [here](https://raw.githubusercontent.com/NCAR/intake-esm-datastore/master/catalogs/pangeo-cmip6.json).

# %%
if util.is_ncar_host():
    col = intake.open_esm_metadatastore("../catalogs/glade-cmip6.json")
else:
    col = intake.open_esm_metadatastore("../catalogs/pangeo-cmip6.json")
col
# Out:
# ESM Collection with 590735 entries:
# 	> 10 activity_id(s)
#
# 	> 21 institution_id(s)
#
# 	> 38 source_id(s)
#
# 	> 60 experiment_id(s)
#
# 	> 161 member_id(s)
#
# 	> 34 table_id(s)
#
# 	> 1022 variable_id(s)
#
# 	> 11 grid_label(s)
#
# 	> 59 dcpp_init_year(s)
#
# 	> 222 version(s)
#
# 	> 4275 time_range(s)
#
# 	> 590735 path(s)

# %% [markdown]
# `intake-esm` is build on top of [pandas](https://pandas.pydata.org/pandas-docs/stable). It is possible to view the `pandas.DataFrame` as follows.

# %%
col.df.head()
# Out:
#   activity_id institution_id source_id experiment_id member_id table_id  \
# 0  AerChemMIP            BCC  BCC-ESM1        ssp370  r2i1p1f1     Amon
# 1  AerChemMIP            BCC  BCC-ESM1        ssp370  r2i1p1f1     Amon
# 2  AerChemMIP            BCC  BCC-ESM1        ssp370  r2i1p1f1     Amon
# 3  AerChemMIP            BCC  BCC-ESM1        ssp370  r2i1p1f1     Amon
# 4  AerChemMIP            BCC  BCC-ESM1        ssp370  r2i1p1f1     Amon
#
#   variable_id grid_label  dcpp_init_year    version     time_range  \
# 0        hfls         gn             NaN  v20190624  201501-205512
# 1          va         gn             NaN  v20190624  201501-205512
# 2         tas         gn             NaN  v20190624  201501-205512
# 3        rsds         gn             NaN  v20190624  201501-205512
# 4          pr         gn             NaN  v20190624  201501-205512
#
#                                                 path
# 0  /glade/collections/cmip/CMIP6/AerChemMIP/BCC/B...
# 1  /glade/collections/cmip/CMIP6/AerChemMIP/BCC/B...
# 2  /glade/collections/cmip/CMIP6/AerChemMIP/BCC/B...
# 3  /glade/collections/cmip/CMIP6/AerChemMIP/BCC/B...
# 4  /glade/collections/cmip/CMIP6/AerChemMIP/BCC/B...

# %% [markdown]
# It is possible to interact with the `DataFrame`; for instance, we can see what the "attributes" of the datasets are by printing the columns.

# %%
col.df.columns
# Out:
# Index(['activity_id', 'institution_id', 'source_id', 'experiment_id',
#        'member_id', 'table_id', 'variable_id', 'grid_label', 'dcpp_init_year',
#        'version', 'time_range', 'path'],
#       dtype='object')

# %% [markdown]
# ### Search and discovery
#
# #### Finding unique entries
# Let's query the data to see what models ("source_id"), experiments ("experiment_id") and temporal frequencies ("table_id") are available.

# %%
import pprint 
uni_dict = col.unique(['source_id', 'experiment_id', 'table_id'])
pprint.pprint(uni_dict, compact=True)
# Out:
# {'experiment_id': {'count': 60,
#                    'values': ['ssp370', 'histSST-piNTCF', 'histSST',
#                               'histSST-1950HC', 'hist-1950HC', 'hist-piNTCF',
#                               'piClim-NTCF', 'ssp370SST-lowNTCF',
#                               'ssp370-lowNTCF', 'ssp370SST', 'amip-future4K',
#                               'amip-m4K', 'a4SST', 'aqua-p4K', 'piSST',
#                               'amip-4xCO2', 'a4SSTice', 'amip-p4K',
#                               'aqua-control', 'aqua-4xCO2', 'abrupt-4xCO2',
#                               'historical', 'piControl', 'amip', '1pctCO2',
#                               'esm-hist', 'esm-piControl', 'ssp245', 'ssp585',
#                               'ssp126', 'dcppA-hindcast',
#                               'dcppC-hindcast-noPinatubo',
#                               'dcppC-hindcast-noElChichon', 'dcppA-assim',
#                               'dcppC-hindcast-noAgung', 'highresSST-present',
#                               'land-hist-princeton', 'land-hist-cruNcep',
#                               'land-hist', 'deforest-globe',
#                               'esm-ssp585-ssp126Lu', 'land-cCO2', 'hist-noLu',
#                               'land-crop-noFert', 'ssp370-ssp126Lu',
#                               'ssp126-ssp370Lu', 'land-noLu', 'land-noFire',
#                               'land-hist-altStartYear', 'land-cClim', 'omip1',
#                               'pdSST-piAntSIC', 'pdSST-futAntSIC',
#                               'pdSST-pdSIC', 'pdSST-piArcSIC',
#                               'pdSST-futArcSIC', 'ssp119', 'ssp434', 'ssp460',
#                               'ssp534-over']},
#  'source_id': {'count': 38,
#                'values': ['BCC-ESM1', 'CESM2-WACCM', 'CESM2', 'CNRM-CM6-1',
#                           'CNRM-ESM2-1', 'BCC-CSM2-MR', 'FGOALS-f3-L',
#                           'FGOALS-g3', 'SAM0-UNICON', 'UKESM1-0-LL',
#                           'HadGEM3-GC31-LL', 'HadGEM3-GC31-MM', 'AWI-CM-1-1-MR',
#                           'GFDL-AM4', 'GFDL-ESM4', 'GFDL-CM4', 'GISS-E2-1-H',
#                           'GISS-E2-1-G', 'CanESM5', 'E3SM-1-0', 'CAMS-CSM1-0',
#                           'MCM-UA-1-0', 'EC-Earth3-LR', 'EC-Earth3',
#                           'EC-Earth3-Veg', 'MRI-ESM2-0', 'NESM3', 'MIROC-ES2L',
#                           'MIROC6', 'IPSL-CM6A-LR', 'NorCPM1', 'NorESM2-LM',
#                           'FIO-ESM-2-0', 'NICAM16-7S', 'NICAM16-8S',
#                           'NICAM16-9S', 'IPSL-CM6A-ATM-HR', 'MPI-ESM1-2-HR']},
#  'table_id': {'count': 34,
#               'values': ['Amon', 'AERmonZ', 'CFmon', 'day', 'EdayZ', 'Eday',
#                          'CFday', 'EmonZ', 'AERday', 'Emon', 'fx', 'Lmon',
#                          'AERmon', 'Ofx', 'Omon', 'SImon', 'Oyr', 'AERhr',
#                          'Eyr', 'LImon', 'SIday', '6hrPlev', 'CFsubhr',
#                          '6hrLev', 'Oday', 'ImonGre', 'ImonAnt', 'Efx',
#                          'IfxGre', '3hr', '6hrPlevPt', 'E1hr', 'E3hr',
#                          'CF3hr']}}

# %% [markdown]
# #### Searching for specific datasets
#
# Let's find all the dissolved oxygen data at annual frequency from the ocean for the `historical` and `ssp585` experiments.

# %%
cat = col.search(experiment_id=['historical', 'ssp585'], table_id='Oyr', variable_id='o2', grid_label='gn')
cat.df
# Out:
#         activity_id institution_id      source_id experiment_id member_id  \
# 42454          CMIP           NCAR    CESM2-WACCM    historical  r2i1p1f1
# 44704          CMIP           NCAR    CESM2-WACCM    historical  r1i1p1f1
# 46954          CMIP           NCAR    CESM2-WACCM    historical  r3i1p1f1
# 263234         CMIP          CCCma        CanESM5    historical  r2i1p1f1
# 263717         CMIP          CCCma        CanESM5    historical  r5i1p1f1
# ...             ...            ...            ...           ...       ...
# 560932  ScenarioMIP           DKRZ  MPI-ESM1-2-HR        ssp585  r1i1p1f1
# 560933  ScenarioMIP           DKRZ  MPI-ESM1-2-HR        ssp585  r1i1p1f1
# 560934  ScenarioMIP           DKRZ  MPI-ESM1-2-HR        ssp585  r1i1p1f1
# 589961  ScenarioMIP          MIROC     MIROC-ES2L        ssp585  r1i1p1f2
# 590561  ScenarioMIP           IPSL   IPSL-CM6A-LR        ssp585  r1i1p1f1
#
#        table_id variable_id grid_label  dcpp_init_year    version time_range  \
# 42454       Oyr          o2         gn             NaN  v20190917  1850-2014
# 44704       Oyr          o2         gn             NaN  v20190917  1850-2014
# 46954       Oyr          o2         gn             NaN  v20190917  1850-2014
# 263234      Oyr          o2         gn             NaN  v20190429  1850-2014
# 263717      Oyr          o2         gn             NaN  v20190429  1850-2014
# ...         ...         ...        ...             ...        ...        ...
# 560932      Oyr          o2         gn             NaN  v20190710  2030-2034
# 560933      Oyr          o2         gn             NaN  v20190710  2085-2089
# 560934      Oyr          o2         gn             NaN  v20190710  2055-2059
# 589961      Oyr          o2         gn             NaN  v20190823  2015-2100
# 590561      Oyr          o2         gn             NaN  v20190119  2015-2100
#
#                                                      path
# 42454   /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2-...
# 44704   /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2-...
# 46954   /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2-...
# 263234  /glade/collections/cmip/CMIP6/CMIP/CCCma/CanES...
# 263717  /glade/collections/cmip/CMIP6/CMIP/CCCma/CanES...
# ...                                                   ...
# 560932  /glade/collections/cmip/CMIP6/ScenarioMIP/DKRZ...
# 560933  /glade/collections/cmip/CMIP6/ScenarioMIP/DKRZ...
# 560934  /glade/collections/cmip/CMIP6/ScenarioMIP/DKRZ...
# 589961  /glade/collections/cmip/CMIP6/ScenarioMIP/MIRO...
# 590561  /glade/collections/cmip/CMIP6/ScenarioMIP/IPSL...
#
# [93 rows x 12 columns]

# %% [markdown]
# ### Loading data
#
# The best part about `intake-esm` is that it enables loading data directly into an [xarray.Dataset](http://xarray.pydata.org/en/stable/api.html#dataset).
#
# Note that data on the cloud are in
# [zarr](https://zarr.readthedocs.io/en/stable/) and data on
# [glade](https://www2.cisl.ucar.edu/resources/storage-and-file-systems/glade-file-spaces) are stored as
# [netCDF](https://www.unidata.ucar.edu/software/netcdf/) files. This is opaque to the user!
#
# `intake-esm` has rules for aggegating datasets; these rules are defined in the collection-specification file.

# %%
dset_dict = cat.to_dataset_dict(zarr_kwargs={'consolidated': True, 'decode_times': False}, 
                                cdf_kwargs={'chunks': {}, 'decode_times': False})
# Out:
# xarray will load the datasets with dask using a single chunk for all arrays.
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#
# --> There will be 9 groups

# %% [markdown]
# `dset_dict` is a dictionary of `xarray.Dataset`'s; its keys are constructed to refer to compatible groups.

# %%
dset_dict.keys()
# Out:
# dict_keys(['CMIP.CCCma.CanESM5.historical.Oyr.gn', 'CMIP.IPSL.IPSL-CM6A-LR.historical.Oyr.gn', 'CMIP.MIROC.MIROC-ES2L.historical.Oyr.gn', 'CMIP.NCAR.CESM2-WACCM.historical.Oyr.gn', 'CMIP.NCC.NorESM2-LM.historical.Oyr.gn', 'ScenarioMIP.CCCma.CanESM5.ssp585.Oyr.gn', 'ScenarioMIP.DKRZ.MPI-ESM1-2-HR.ssp585.Oyr.gn', 'ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp585.Oyr.gn', 'ScenarioMIP.MIROC.MIROC-ES2L.ssp585.Oyr.gn'])

# %% [markdown]
# We can access a particular dataset as follows.

# %%
dset_dict['CMIP.CCCma.CanESM5.historical.Oyr.gn']
# Out:
# <xarray.Dataset>
# Dimensions:             (bnds: 2, i: 360, j: 291, lev: 45, member_id: 20, time: 165, vertices: 4)
# Coordinates:
#   * time                (time) float64 182.5 547.5 912.5 ... 5.968e+04 6.004e+04
#   * j                   (j) int32 0 1 2 3 4 5 6 ... 284 285 286 287 288 289 290
#   * i                   (i) int32 0 1 2 3 4 5 6 ... 353 354 355 356 357 358 359
#   * lev                 (lev) float64 3.047 9.454 16.36 ... 5.375e+03 5.625e+03
#   * member_id           (member_id) <U9 'r12i1p1f1' 'r14i1p1f1' ... 'r9i1p1f1'
# Dimensions without coordinates: bnds, vertices
# Data variables:
#     vertices_latitude   (j, i, vertices) float64 -78.29 -78.49 ... 50.11 50.11
#     lev_bnds            (lev, bnds) float64 0.0 6.194 6.194 ... 5.5e+03 5.75e+03
#     time_bnds           (time, bnds) float64 dask.array<chunksize=(165, 2), meta=np.ndarray>
#     vertices_longitude  (j, i, vertices) float64 74.0 74.0 73.0 ... 72.95 73.0
#     latitude            (j, i) float64 -78.39 -78.39 -78.39 ... 50.23 50.01
#     longitude           (j, i) float64 73.5 74.5 75.5 76.5 ... 72.95 72.96 72.99
#     o2                  (member_id, time, lev, j, i) float32 dask.array<chunksize=(1, 165, 45, 291, 360), meta=np.ndarray>
# Attributes:
#     activity_id:                CMIP
#     references:                 Geophysical Model Development Special issue o...
#     source:                     CanESM5 (2019): \naerosol: interactive\natmos...
#     branch_time_in_child:       0.0
#     institution_id:             CCCma
#     license:                    CMIP6 model data produced by The Government o...
#     CCCma_pycmor_hash:          33c30511acc319a98240633965a04ca99c26427e
#     branch_method:              Spin-up documentation
#     YMDH_branch_time_in_child:  1850:01:01:00
#     table_info:                 Creation Date:(20 February 2019) MD5:374fbe5a...
#     source_type:                AOGCM
#     sub_experiment:             none
#     table_id:                   Oyr
#     CCCma_model_hash:           55f484f90aff0e32c5a8e92a42c6b9ae7ffe6224
#     parent_source_id:           CanESM5
#     initialization_index:       1
#     parent_activity_id:         CMIP
#     cmor_version:               3.4.0
#     experiment_id:              historical
#     sub_experiment_id:          none
#     nominal_resolution:         100 km
#     parent_experiment_id:       piControl
#     parent_mip_era:             CMIP6
#     CCCma_parent_runid:         rc3.1-pictrl
#     institution:                Canadian Centre for Climate Modelling and Ana...
#     forcing_index:              1
#     parent_variant_label:       r1i1p1f1
#     realm:                      ocnBgchem
#     source_id:                  CanESM5
#     tracking_id:                hdl:21.14100/b74e3b07-ed7b-43b3-976f-3b4a55c5...
#     history:                    2019-05-02T13:55:48Z ;rewrote data to be cons...
#     experiment:                 all-forcing simulation of the recent past
#     version:                    v20190429
#     Conventions:                CF-1.7 CMIP-6.2
#     contact:                    ec.cccma.info-info.ccmac.ec@canada.ca
#     grid:                       ORCA1 tripolar grid, 1 deg with refinement to...
#     frequency:                  yr
#     title:                      CanESM5 output prepared for CMIP6
#     mip_era:                    CMIP6
#     parent_time_units:          days since 1850-01-01 0:0:0.0
#     data_specs_version:         01.00.29
#     external_variables:         areacello volcello
#     physics_index:              1
#     grid_label:                 gn
#     product:                    model-output
#     variable_id:                o2

# %%
cat_fx = col.search(table_id='Ofx', grid_label='gn',
                    variable_id='volcello')
cat_fx.df
# Out:
#         activity_id institution_id      source_id        experiment_id  \
# 3391     AerChemMIP           NCAR    CESM2-WACCM          hist-1950HC
# 4919     AerChemMIP           NCAR    CESM2-WACCM          hist-piNTCF
# 8650     AerChemMIP           NCAR    CESM2-WACCM       ssp370-lowNTCF
# 9856     AerChemMIP           NCAR          CESM2       ssp370-lowNTCF
# 10686    AerChemMIP           NCAR          CESM2       ssp370-lowNTCF
# 37088          CMIP           NCAR    CESM2-WACCM         abrupt-4xCO2
# 47238          CMIP           NCAR    CESM2-WACCM            piControl
# 60320          CMIP           NCAR    CESM2-WACCM              1pctCO2
# 63723          CMIP           NCAR          CESM2         abrupt-4xCO2
# 63724          CMIP           NCAR          CESM2         abrupt-4xCO2
# 84993          CMIP           NCAR          CESM2           historical
# 87228          CMIP           NCAR          CESM2           historical
# 89659          CMIP           NCAR          CESM2           historical
# 91894          CMIP           NCAR          CESM2           historical
# 94129          CMIP           NCAR          CESM2           historical
# 96471          CMIP           NCAR          CESM2           historical
# 101348         CMIP           NCAR          CESM2           historical
# 106681         CMIP           NCAR          CESM2           historical
# 111892         CMIP           NCAR          CESM2           historical
# 117254         CMIP           NCAR          CESM2           historical
# 122467         CMIP           NCAR          CESM2           historical
# 124994         CMIP           NCAR          CESM2             esm-hist
# 129694         CMIP           NCAR          CESM2             esm-hist
# 134653         CMIP           NCAR          CESM2            piControl
# 157675         CMIP           NCAR          CESM2        esm-piControl
# 170313         CMIP           NCAR          CESM2              1pctCO2
# 173677         CMIP            CAS    FGOALS-f3-L           historical
# 292509         CMIP             UA     MCM-UA-1-0            piControl
# 292586         CMIP             UA     MCM-UA-1-0              1pctCO2
# 493516        LUMIP           NCAR          CESM2  esm-ssp585-ssp126Lu
# 494566        LUMIP           NCAR          CESM2            hist-noLu
# 496440        LUMIP           NCAR          CESM2            hist-noLu
# 497190        LUMIP           NCAR          CESM2            hist-noLu
# 499064        LUMIP           NCAR          CESM2       deforest-globe
# 499751        LUMIP           NCAR          CESM2      ssp370-ssp126Lu
# 500686        LUMIP           NCAR          CESM2      ssp126-ssp370Lu
# 562539  ScenarioMIP           DKRZ  MPI-ESM1-2-HR               ssp126
#
#         member_id table_id variable_id grid_label  dcpp_init_year    version  \
# 3391     r1i1p1f1      Ofx    volcello         gn             NaN  v20190606
# 4919     r1i2p1f1      Ofx    volcello         gn             NaN  v20190531
# 8650     r1i2p1f1      Ofx    volcello         gn             NaN  v20191001
# 9856     r3i2p1f1      Ofx    volcello         gn             NaN  v20191001
# 10686    r2i2p1f1      Ofx    volcello         gn             NaN  v20191001
# 37088    r1i1p1f1      Ofx    volcello         gn             NaN  v20190425
# 47238    r1i1p1f1      Ofx    volcello         gn             NaN  v20190320
# 60320    r1i1p1f1      Ofx    volcello         gn             NaN  v20190425
# 63723    r1i1p1f1      Ofx    volcello         gn             NaN  v20190425
# 63724    r1i1p1f1      Ofx    volcello         gn             NaN  v20190927
# 84993    r2i1p1f1      Ofx    volcello         gn             NaN  v20190308
# 87228    r5i1p1f1      Ofx    volcello         gn             NaN  v20190308
# 89659    r1i1p1f1      Ofx    volcello         gn             NaN  v20190308
# 91894    r4i1p1f1      Ofx    volcello         gn             NaN  v20190308
# 94129    r3i1p1f1      Ofx    volcello         gn             NaN  v20190308
# 96471    r9i1p1f1      Ofx    volcello         gn             NaN  v20190311
# 101348   r8i1p1f1      Ofx    volcello         gn             NaN  v20190311
# 106681  r10i1p1f1      Ofx    volcello         gn             NaN  v20190313
# 111892   r7i1p1f1      Ofx    volcello         gn             NaN  v20190311
# 117254  r11i1p1f1      Ofx    volcello         gn             NaN  v20190514
# 122467   r6i1p1f1      Ofx    volcello         gn             NaN  v20190308
# 124994   r2i1p1f1      Ofx    volcello         gn             NaN  v20190802
# 129694   r1i1p1f1      Ofx    volcello         gn             NaN  v20190802
# 134653   r1i1p1f1      Ofx    volcello         gn             NaN  v20190320
# 157675   r1i1p1f1      Ofx    volcello         gn             NaN  v20190723
# 170313   r1i1p1f1      Ofx    volcello         gn             NaN  v20190425
# 173677   r1i1p1f1      Ofx    volcello         gn             NaN  v20190918
# 292509   r1i1p1f1      Ofx    volcello         gn             NaN  v20190731
# 292586   r1i1p1f1      Ofx    volcello         gn             NaN  v20190731
# 493516   r1i1p1f1      Ofx    volcello         gn             NaN  v20190802
# 494566   r2i1p1f1      Ofx    volcello         gn             NaN  v20190522
# 496440   r1i1p1f1      Ofx    volcello         gn             NaN  v20190401
# 497190   r3i1p1f1      Ofx    volcello         gn             NaN  v20190522
# 499064   r1i1p1f1      Ofx    volcello         gn             NaN  v20190401
# 499751   r1i1p1f1      Ofx    volcello         gn             NaN  v20190605
# 500686   r1i1p1f1      Ofx    volcello         gn             NaN  v20190605
# 562539   r1i1p1f1      Ofx    volcello         gn             NaN  v20190710
#
#        time_range                                               path
# 3391          NaN  /glade/collections/cmip/CMIP6/AerChemMIP/NCAR/...
# 4919          NaN  /glade/collections/cmip/CMIP6/AerChemMIP/NCAR/...
# 8650          NaN  /glade/collections/cmip/CMIP6/AerChemMIP/NCAR/...
# 9856          NaN  /glade/collections/cmip/CMIP6/AerChemMIP/NCAR/...
# 10686         NaN  /glade/collections/cmip/CMIP6/AerChemMIP/NCAR/...
# 37088         NaN  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2-...
# 47238         NaN  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2-...
# 60320         NaN  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2-...
# 63723         NaN  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 63724         NaN  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 84993         NaN  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 87228         NaN  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 89659         NaN  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 91894         NaN  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 94129         NaN  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 96471         NaN  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 101348        NaN  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 106681        NaN  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 111892        NaN  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 117254        NaN  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 122467        NaN  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 124994        NaN  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 129694        NaN  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 134653        NaN  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 157675        NaN  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 170313        NaN  /glade/collections/cmip/CMIP6/CMIP/NCAR/CESM2/...
# 173677        NaN  /glade/collections/cmip/CMIP6/CMIP/CAS/FGOALS-...
# 292509        NaN  /glade/collections/cmip/CMIP6/CMIP/UA/MCM-UA-1...
# 292586        NaN  /glade/collections/cmip/CMIP6/CMIP/UA/MCM-UA-1...
# 493516        NaN  /glade/collections/cmip/CMIP6/LUMIP/NCAR/CESM2...
# 494566        NaN  /glade/collections/cmip/CMIP6/LUMIP/NCAR/CESM2...
# 496440        NaN  /glade/collections/cmip/CMIP6/LUMIP/NCAR/CESM2...
# 497190        NaN  /glade/collections/cmip/CMIP6/LUMIP/NCAR/CESM2...
# 499064        NaN  /glade/collections/cmip/CMIP6/LUMIP/NCAR/CESM2...
# 499751        NaN  /glade/collections/cmip/CMIP6/LUMIP/NCAR/CESM2...
# 500686        NaN  /glade/collections/cmip/CMIP6/LUMIP/NCAR/CESM2...
# 562539        NaN  /glade/collections/cmip/CMIP6/ScenarioMIP/DKRZ...
